# %%
import random
from newspaper import Article
import string
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#download the punkt package
nltk.download('punkt',quiet=True)
article = Article('http://en.wikipedia.org/wiki/Coronavirus')
article.download()
article.parse()
article.nlp()
corpus = article.text
article = Article('new url')
#print(corpus)

#tokennisation
test = corpus
senstence_list = nltk.sent_tokenize(test)
#print(senstence_list)

#A function to return a random greeting message to user

def greet_res(text):
    text = text.lower()
    
    #bot greeting response
    bot_greeting = ['hello','hiii','hi','hey','hlo','helo','wassup','hye']
   
    #user greeting response
    user_greeting = ['hello','hiii','hi','hey','hlo','helo','wassup','hellooo','hye']
    
    for word in text.split():
        if word in user_greeting:
            return random.choice(bot_greeting)

#function to sort the Index
def index_sort(list_var):
    length = len(list_var)
    list_index = list(range(0,length))
    
    x = list_var
    for i in range(length):
        for j in range(length):
            if x[list_index[i]] > x[list_index[j]]:
                 #swap
                 temp = list_index[i]
                 list_index[i] = list_index[j]
                 list_index[j] = temp
    
    return list_index


#function for bot response
def bot_res(user_input):
    user_input = user_input.lower()
    senstence_list.append(user_input)
    bot_res = ''
    cm = CountVectorizer().fit_transform(senstence_list)
    s_score = cosine_similarity(cm[-1],cm)
    s_score_list = s_score.flatten()
    #print( s_score_list)
    index = index_sort(s_score_list)
    index = index[1:]
    res_flag = 0
    j=0
    for i in range(len(index)):
                 if s_score_list[i] > 0.0:
                     bot_res = bot_res+' '+senstence_list[index[i]]
                     res_flag = 1
                     j = j+1
                 if j > 2:
                     break
                 
    if res_flag == 0:
        bot_res = bot_res+' I apologise I can not answer your question please ask something else '

    senstence_list.remove(user_input)
    return bot_res
    
                 
        
    
#start the chat
print("Covid Helpline : I am here to help you for getting information about the Corona Virus")

exit_list = ['bye','exit','byee','break','stop','quit']
while(True):
    user_input = input()
    if  user_input.lower() in exit_list:
        print("Bot : Thanks for quries. See you later !")
        break
    elif greet_res(user_input)!= None:
         print("Bot : "+ greet_res(user_input))
    else:
         print("\n","Bot : "+ bot_res(user_input))
# Out:
# Covid Helpline : I am here to help you for getting information about the Corona Virus
# hello
# Bot : hye
# tell me about corona virus
#
#  Bot :  [132] The virus is transmitted by aerosol and food contaminated by feces. The novel virus caused a cold in volunteers and, like B814, was inactivated by ether. The final name for the virus is Middle East respiratory syndrome coronavirus (MERS-CoV).
# symptom of corona virus
#
#  Bot :  [128] Infectious bronchitis virus is one of a number of strains of the species Avian coronavirus. [118] As of December 2019, 2,468 cases of MERS-CoV infection had been confirmed by laboratory tests, 851 of which were fatal, a mortality rate of approximately 34.5%. [137] Feline enteric coronavirus is a pathogen of minor clinical significance, but spontaneous mutation of this virus can result in feline infectious peritonitis (FIP), a disease with high mortality.
# covid19
#
#  Bot :  I apologise I can not answer your question please ask something else
